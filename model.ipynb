# %%
from ultralytics import YOLO

# %%
data = r"E:\Mega Project\data.yaml"

# %%
model = YOLO("yolov8n.pt")
model.train(data=data, epochs=8)
# Out:
# New https://pypi.org/project/ultralytics/8.3.229 available  Update with 'pip install -U ultralytics'
# Ultralytics 8.3.214  Python-3.13.9 torch-2.9.0+cpu CPU (AMD Ryzen 5 7535HS with Radeon Graphics)
# ...

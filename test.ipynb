# %%
from ultralytics import YOLO

# %%
model = YOLO(r"E:\Mega Project\yolov8\model\runs\detect\train2\weights\best.pt")

# %%
results = model.predict(source=r"E:/Mega Project/dataset/images/test/VID_20250228_135247_mp4-0195_jpg.rf.4b522e20b8a52483fb5269fd97738124.jpg", save=True, conf=0.25)
# Out:
# image 1/1 E:\Mega Project\dataset\images\test\VID_20250228_135247_mp4-0195_jpg.rf.4b522e20b8a52483fb5269fd97738124.jpg: 384x640 1 Coriander leaves, 2 Lemons, 1 Bitter Gourd, 3 Eggplants, 5 Green Chillis, 54.4ms
# Speed: 2.2ms preprocess, 54.4ms inference, 5.8ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to E:\Mega Project\yolov8\model\runs\detect\predict4

# %%
from IPython.display import Image, display
display(Image(filename=r"E:\Mega Project\yolov8\model\runs\detect\predict2\VID_20250228_135247_mp4-0195_jpg.rf.4b522e20b8a52483fb5269fd97738124.jpg"))

# %%
results = model.predict(source=r"C:\Users\Gautam\Downloads\vege.jpeg", save=True, conf=0.25)
# Out:
# image 1/1 C:\Users\Gautam\Downloads\vege.jpeg: 448x640 7 Tomatos, 1 Green Beans, 1 Cauliflower, 1 Capsicum, 59.8ms
# Speed: 6.1ms preprocess, 59.8ms inference, 1.5ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to E:\Mega Project\yolov8\model\runs\detect\predict2

# %%
from IPython.display import Image, display
display(Image(filename=r"E:/Mega Project/dataset/images/test/VID_20250228_135247_mp4-0195_jpg.rf.4b522e20b8a52483fb5269fd97738124.jpg"))
